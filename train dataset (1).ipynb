# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\sreem\OneDrive\Desktop\train.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.size
# Out:
# 6600816

# %%
df.head(100)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# ..      ...        ...    ...    ...         ...           ...
# 95  1000019  P00251642      M   0-17          10             A
# 96  1000019  P00244842      M   0-17          10             A
# 97  1000021  P00220242      M  18-25          16             B
# 98  1000022  P00351142      M  18-25          15             A
# 99  1000022  P00213242      M  18-25          15             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# ...

# %%
df.tail(15)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550053  1006017  P00371644      F  36-45           7             B
# 550054  1006018  P00370293      M  36-45           1             C
# 550055  1006019  P00372445      M  26-35           0             A
# 550056  1006022  P00375436      M  26-35          17             C
# 550057  1006023  P00370853      M  26-35           0             C
# 550058  1006024  P00372445      M  26-35          12             A
# 550059  1006025  P00370853      F  26-35           1             B
# 550060  1006026  P00371644      M  36-45           6             C
# 550061  1006029  P00372445      F  26-35           1             C
# 550062  1006032  P00372445      M  46-50           7             A
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df2=df.dropna()

# %%
df2.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df2.loc[:,'Age'].head(10)
# Out:
# 1      0-17
# 6     46-50
# 13    26-35
# 14    51-55
# 16    51-55
# 18    36-45
# 19    26-35
# 24    26-35
# 28    26-35
# 29    36-45
# Name: Age, dtype: object

# %%
df2.sort_index()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 545902  1006039  P00064042      F  46-50           0             B
# 545904  1006040  P00081142      M  26-35           6             B
# 545907  1006040  P00277642      M  26-35           6             B
# 545908  1006040  P00127642      M  26-35           6             B
# 545914  1006040  P00217442      M  26-35           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
df2.sort_values(by=['Stay_In_Current_City_Years'])
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 193792  1005924  P00114342      M  36-45           0             B
# 300340  1004227  P00000642      M  26-35          19             A
# 478796  1001723  P00165442      M  36-45          17             C
# 127553  1001647  P00339842      M  18-25          18             B
# 127559  1001647  P00196542      M  18-25          18             B
# ...         ...        ...    ...    ...         ...           ...
# 325076  1002015  P00025442      M  18-25           4             B
# 325078  1002015  P00028442      M  18-25           4             B
# 325090  1002015  P00150842      M  18-25           4             B
# 397764  1001224  P00087042      M  51-55          13             B
# 154738  1005911  P00242742      F  26-35          17             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 193792                          0               1                   1
# ...

# %%
df2.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df2['Gender'].describe()
# Out:
# count     166821
# unique         2
# top            M
# freq      129227
# Name: Gender, dtype: object

# %%
df2['Age'].describe()
# Out:
# count     166821
# unique         7
# top        26-35
# freq       66942
# Name: Age, dtype: object

# %%
df2['City_Category'].describe()
# Out:
# count     166821
# unique         3
# top            B
# freq       69243
# Name: City_Category, dtype: object

# %%
df2['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df2['Age'].unique()
# Out:
# array(['0-17', '46-50', '26-35', '51-55', '36-45', '18-25', '55+'],
#       dtype=object)

# %%
df2['City_Category'].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df2['Age'].value_counts()
# Out:
# Age
# 26-35    66942
# 36-45    33285
# 18-25    31316
# 46-50    13374
# 51-55    11166
# 55+       5865
# 0-17      4873
# Name: count, dtype: int64

# %%
sns.countplot(x=df2['Age'])
plt.title("Count Vs Age")
# Out:
# Text(0.5, 1.0, 'Count Vs Age')

# %%
sns.countplot(x=df2['Gender'])
plt.title("Count Vs Gender")
# Out:
# Text(0.5, 1.0, 'Count Vs Gender')

# %%
df2.groupby('Gender').sum()
# Out:
#              User_ID                                         Product_ID  \
# Gender
# F        37712620681  P00248942P00231342P0096642P00085942P00182642P0...
# M       129615022478  P00184942P00145042P00036842P00249542P00303442P...
#
#                                                       Age  Occupation  \
# Gender
# F       0-1751-5551-5536-4536-4536-4536-4536-4536-4536...      256869
# M       46-5026-3536-4526-3526-3526-3546-5026-3551-555...     1107541
#
#                                             City_Category  \
# Gender
# F       AAABBBBBBBBCCBBBBBBBBBACACAAABBBAAACCCCAACCCCB...
# M       BABCCCCACCAAAAAAAABBBBBBBBCCBCCCBBBBBBBBBBCCCB...
#
#                                Stay_In_Current_City_Years  Marital_Status  \
# Gender
# F       2114+4+4+4+4+4+4+4+1033333333332011114+4+4+111...           15516
# M       2114+4+03100333334+4+4+333333334+4+21120000000...           51686
#
#         Product_Category_1  Product_Category_2  Product_Category_3    Purchase
# Gender
# ...

# %%
sns.boxplot(x=df['Gender'],y=df['Occupation'])
plt.title("Gender Vs Occupation")
plt.grid()
